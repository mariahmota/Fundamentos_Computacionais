# %% [markdown]
# <a href="https://colab.research.google.com/github/mariahmota/Fundamentos_Computacionais/blob/main/Equacoes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Unidade 3 - Programação Orientada a Equações e Modular**

# %% [markdown]
# ### ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### ![image.png](data:image/png;base64,...)

# %%
def mixer(FA, FB, xA, xB):
  try:
    if FA < 0 or FB < 0:
      raise ValueError('Vazões não podem ser negativas')
    if xA < 0 or xA > 1 or xB < 0 or xB > 1:
      raise ValueError('Composições devem estar entre 0 e 1.')
    F = FA + FB
    xf = (FA*xA + FB*xB)/F

  except ValueError as e:
    print(f'Ocorreu um erro: {e}')

  return F, xf

result1 = mixer(100, 50, 0.1, 0.3)
print(f'F = {result1[0]} e xf = {result1[1]:.2f}')

result2 = mixer(50, 50, 0.15, 0.3)
print(f'F = {result2[0]} e xf = {result2[1]}')
# Out:
# F = 150 e xf = 0.17
# F = 100 e xf = 0.225
