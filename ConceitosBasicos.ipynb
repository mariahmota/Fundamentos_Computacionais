# %% [markdown]
# <a href="https://colab.research.google.com/github/mariahmota/Fundamentos_Computacionais/blob/main/ConceitosBasicosII.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Unidade 1 - Ambiente de desenvolvimento em Python**

# %% [markdown]
# ### The Zen of Python

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# ### Horário e data

# %%
from datetime import datetime

# Captura o horário e data atual
agora = datetime.now()
data = agora.strftime("%d/%m/%Y")
hora = agora.strftime("%H:%M:%S")

# Mensagem personalizada
nome = "Julio Dutra"
mensagem = f"👋 Olá, {nome}! \nHoje é {data}, e agora são {hora}."

print(mensagem)
print("🚀 Bem-vindo ao mundo da programação!")
# Out:
# 👋 Olá, Julio Dutra!
# Hoje é 14/03/2026, e agora são 22:42:13.
# 🚀 Bem-vindo ao mundo da programação!

# %% [markdown]
# ## Exercícios

# %% [markdown]
# ### ![image.png](data:image/png;base64,...)

# %%
T1 = 350
T2 = 280
P = 1.5

print('Verdadeiro ou falso:\n')
print('1. T1>T2 and P>1 ->',T1>T2 and P>1)
print('2. T2>=300 or P<1 ->', T2>=300 or P<1)
print('3. not(P == 1.5) ->', not(P == 1.5))
print('4. (T1-T2)>100 and (P>=1.5) ->', (T1-T2)>100 and (P>=1.5))
print('5. (T1/T2<1.5) or (T2 == 280) ->', (T1/T2<1.5) or (T2 == 280))
# Out:
# Verdadeiro ou falso:
#
# 1. T1>T2 and P>1 -> True
# 2. T2>=300 or P<1 -> False
# 3. not(P == 1.5) -> False
# 4. (T1-T2)>100 and (P>=1.5) -> False
# 5. (T1/T2<1.5) or (T2 == 280) -> True

# %% [markdown]
# ### ![image.png](data:image/png;base64,...)

# %%
import numpy as np

concentracao = int(input('Concentração do ácido em mol/L: '))

pH = -np.log(concentracao)
print('pH =', pH)
# Out:
# Concentração do ácido em mol/L: 10
# pH = -2.302585092994046
